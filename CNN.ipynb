# %%
import tensorflow as tf
from tensorflow.keras import layers,models,datasets
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 475s 3us/step

# %%
(x_train,y_train),(X_test,y_test)=datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
#Normalize
x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0

# %%
classes=['Airoplane','Dog','Horse','Frog','Cat','Deer','Ship','Bird','Truck','Automobiles']

plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(classes[y_train[i][0]])
    plt.axis('off')
plt.show()

# %%
#create CNN model \
x=models.Sequential([layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)),
                     layers.MaxPooling2D(2,2),
layers.Conv2D(64,(3,3),activation='relu',input_shape=(32,32,3)),
                     layers.MaxPooling2D(2,2),
layers.Conv2D(64,(3,3),activation='relu',input_shape=(32,32,3)),
                     

layers.Flatten(),
layers.Dense(32,activation='relu'),
layers.Dense(15,activation='softmax')])

# %%
#Compile The model

x.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
y=x.fit(x_train,y_train, epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3008 - loss: 1.9021 - val_accuracy: 0.4950 - val_loss: 1.4173
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.5130 - loss: 1.3481 - val_accuracy: 0.5454 - val_loss: 1.2704
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.5811 - loss: 1.1759 - val_accuracy: 0.6071 - val_loss: 1.1184
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6233 - loss: 1.0652 - val_accuracy: 0.6223 - val_loss: 1.0745
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.6550 - loss: 0.9804 - val_accuracy: 0.6497 - val_loss: 0.9993
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6767 - loss: 0.9183 - val_accuracy: 0.6557 - val_loss: 0.9938
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.6918 - loss: 0.8712 - val_accuracy: 0.6650 - val_loss: 0.9610
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7117 - loss: 0.8193 - val_accuracy: 0.6800 - val_loss: 0.9348
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7261 - loss: 0.7803 - val_accuracy: 0.6921 - val_loss: 0.9060
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7411 - loss: 0.7385 - val_accuracy: 0.6889 - val_loss: 0.9002

# %%
losses,accuracy=x.evaluate(x_test,y_test)
print(accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6913 - loss: 0.8866
# 0.6866999864578247

# %%
     #Preprocessing
x.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
